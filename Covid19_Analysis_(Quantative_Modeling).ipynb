# %% [markdown]
# # Author :- Hemant Ramkisan Bhutada

# %% [markdown]
# # Covid19_Analysis(Quantitative Modelling)i.e Data Visualization

# %%
# first we will import the libraries required in this notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# we will read the dataset
data = pd.read_csv("covid19.csv")
data
# Out:
#      Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0      1  30/01/20               Kerala                        1
# 1      2  31/01/20               Kerala                        1
# 2      3  01/02/20               Kerala                        2
# 3      4  02/02/20               Kerala                        3
# 4      5  03/02/20               Kerala                        3
# ..   ...       ...                  ...                      ...
# 265  266  21/03/20    Jammu and Kashmir                        4
# 266  267  21/03/20               Ladakh                       13
# 267  268  21/03/20        Uttar Pradesh                       23
# 268  269  21/03/20          Uttarakhand                        3
# 269  270  21/03/20          West Bengal                        3
#
#      ConfirmedForeignNational  Cured  Deaths
# 0                           0      0       0
# 1                           0      0       0
# 2                           0      0       0
# 3                           0      0       0
# 4                           0      0       0
# ..                        ...    ...     ...
# 265                         0      0       0
# 266                         0      0       0
# 267                         1      9       0
# 268                         0      0       0
# 269                         0      0       0
#
# [270 rows x 7 columns]

# %%
# we will print the first five line of our dataset
data.head()
# Out:
#    Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0    1  30/01/20               Kerala                        1
# 1    2  31/01/20               Kerala                        1
# 2    3  01/02/20               Kerala                        2
# 3    4  02/02/20               Kerala                        3
# 4    5  03/02/20               Kerala                        3
#
#    ConfirmedForeignNational  Cured  Deaths
# 0                         0      0       0
# 1                         0      0       0
# 2                         0      0       0
# 3                         0      0       0
# 4                         0      0       0

# %%
# we will drop the unnecssary column which is Sno
data.drop(["Sno"],axis=1,inplace=True)

# %%
# we will group the rows by date to get daily cases count
pp = data.groupby("Date",sort=False).count()
pp
# Out:
#           State/UnionTerritory  ConfirmedIndianNational  \
# Date
# 30/01/20                     1                        1
# 31/01/20                     1                        1
# 01/02/20                     1                        1
# 02/02/20                     1                        1
# 03/02/20                     1                        1
# 04/02/20                     1                        1
# 05/02/20                     1                        1
# 06/02/20                     1                        1
# 07/02/20                     1                        1
# 08/02/20                     1                        1
# 09/02/20                     1                        1
# 10/02/20                     1                        1
# 11/02/20                     1                        1
# 12/02/20                     1                        1
# 13/02/20                     1                        1
# 14/02/20                     1                        1
# 15/02/20                     1                        1
# 16/02/20                     1                        1
# 17/02/20                     1                        1
# 18/02/20                     1                        1
# 19/02/20                     1                        1
# 20/02/20                     1                        1
# 21/02/20                     1                        1
# 22/02/20                     1                        1
# 23/02/20                     1                        1
# 24/02/20                     1                        1
# 25/02/20                     1                        1
# 26/02/20                     1                        1
# 27/02/20                     1                        1
# 28/02/20                     1                        1
# 29/02/20                     1                        1
# 01/03/20                     1                        1
# 02/03/20                     3                        3
# 03/03/20                     4                        4
# 04/03/20                     6                        6
# 05/03/20                     6                        6
# 06/03/20                     6                        6
# 07/03/20                     8                        8
# 08/03/20                     8                        8
# 09/03/20                    12                       12
# 10/03/20                    12                       12
# 11/03/20                    12                       12
# 12/03/20                    13                       13
# 13/03/20                    13                       13
# 14/03/20                    13                       13
# 15/03/20                    14                       14
# 16/03/20                    15                       15
# 17/03/20                    15                       15
# 18/03/20                    17                       17
# 19/03/20                    19                       19
# 20/03/20                    20                       20
# 21/03/20                    22                       22
#
#           ConfirmedForeignNational  Cured  Deaths
# Date
# 30/01/20                         1      1       1
# 31/01/20                         1      1       1
# 01/02/20                         1      1       1
# 02/02/20                         1      1       1
# 03/02/20                         1      1       1
# 04/02/20                         1      1       1
# 05/02/20                         1      1       1
# 06/02/20                         1      1       1
# 07/02/20                         1      1       1
# 08/02/20                         1      1       1
# 09/02/20                         1      1       1
# 10/02/20                         1      1       1
# 11/02/20                         1      1       1
# 12/02/20                         1      1       1
# 13/02/20                         1      1       1
# 14/02/20                         1      1       1
# 15/02/20                         1      1       1
# 16/02/20                         1      1       1
# 17/02/20                         1      1       1
# 18/02/20                         1      1       1
# 19/02/20                         1      1       1
# 20/02/20                         1      1       1
# 21/02/20                         1      1       1
# 22/02/20                         1      1       1
# 23/02/20                         1      1       1
# 24/02/20                         1      1       1
# 25/02/20                         1      1       1
# 26/02/20                         1      1       1
# 27/02/20                         1      1       1
# 28/02/20                         1      1       1
# 29/02/20                         1      1       1
# 01/03/20                         1      1       1
# 02/03/20                         3      3       3
# 03/03/20                         4      4       4
# 04/03/20                         6      6       6
# 05/03/20                         6      6       6
# 06/03/20                         6      6       6
# 07/03/20                         8      8       8
# 08/03/20                         8      8       8
# 09/03/20                        12     12      12
# 10/03/20                        12     12      12
# 11/03/20                        12     12      12
# 12/03/20                        13     13      13
# 13/03/20                        13     13      13
# 14/03/20                        13     13      13
# 15/03/20                        14     14      14
# 16/03/20                        15     15      15
# 17/03/20                        15     15      15
# 18/03/20                        17     17      17
# 19/03/20                        19     19      19
# 20/03/20                        20     20      20
# 21/03/20                        22     22      22

# %%
# we will store the dataframe in new variable
df = pd.DataFrame(pp)

# %%
# we will print the dataframe
df
# Out:
#           State/UnionTerritory  ConfirmedIndianNational  \
# Date
# 30/01/20                     1                        1
# 31/01/20                     1                        1
# 01/02/20                     1                        1
# 02/02/20                     1                        1
# 03/02/20                     1                        1
# 04/02/20                     1                        1
# 05/02/20                     1                        1
# 06/02/20                     1                        1
# 07/02/20                     1                        1
# 08/02/20                     1                        1
# 09/02/20                     1                        1
# 10/02/20                     1                        1
# 11/02/20                     1                        1
# 12/02/20                     1                        1
# 13/02/20                     1                        1
# 14/02/20                     1                        1
# 15/02/20                     1                        1
# 16/02/20                     1                        1
# 17/02/20                     1                        1
# 18/02/20                     1                        1
# 19/02/20                     1                        1
# 20/02/20                     1                        1
# 21/02/20                     1                        1
# 22/02/20                     1                        1
# 23/02/20                     1                        1
# 24/02/20                     1                        1
# 25/02/20                     1                        1
# 26/02/20                     1                        1
# 27/02/20                     1                        1
# 28/02/20                     1                        1
# 29/02/20                     1                        1
# 01/03/20                     1                        1
# 02/03/20                     3                        3
# 03/03/20                     4                        4
# 04/03/20                     6                        6
# 05/03/20                     6                        6
# 06/03/20                     6                        6
# 07/03/20                     8                        8
# 08/03/20                     8                        8
# 37  07/03/20     37
# 38  08/03/20     42
# 39  09/03/20     49
# 40  10/03/20     61
# 41  11/03/20     63
# 42  12/03/20     77
# 43  13/03/20     85
# 44  14/03/20     96
# 45  15/03/20    125
# 46  16/03/20    129
# 47  17/03/20    154
# 48  18/03/20    168
# 49  19/03/20    197
# 50  20/03/20    250
# 51  21/03/20    310

# %%
# line graph of datewise cases
fig, ax = plt.subplots()
fig.set_figwidth(20)
fig.set_figheight(8)
ax.set_xlabel("Date",fontsize=20)
plt.xticks(rotation = 50)
#ax.tick_params(axis="x",bottom=False,labelbottom=False)
ax.set_ylabel("Cases")
ax.plot(df2["Date"],
        df2["Cases"])
plt.title('Corona Datewise cases',fontsize=25)
plt.ylabel('Number of cases',fontsize=20)
plt.show()

# %%
# Bar graph of Datewise cases
fig, ax = plt.subplots()
fig.set_figwidth(20)
fig.set_figheight(8)
Date = df2["Date"]
Cases = df2["Cases"]
sns.barplot(x = Date,
           y = Cases,
           palette = "tab10")
plt.xticks(rotation = 50)
plt.title('Corona Datewise cases',fontsize=25)
plt.ylabel('Number of cases',fontsize=20)
plt.xlabel("Date",fontsize=20)
plt.show()

# %% [markdown]
# # Country Wise Plot

# %%
#Specified the path to my dataset and loaded it in a dataframe
df_covid = pd.read_csv('time_series_2019-ncov-Confirmed.csv',index_col=0)
df_covid
# Out:
#                Country/Region       Lat      Long  1/22/20  1/23/20  1/24/20  \
# Province/State
# NaN                  Thailand        15       101        2        3        5
# NaN                     Japan        36       138        2        1        2
# NaN                 Singapore    1.2833  103.8333        0        1        3
# NaN                     Nepal   28.1667     84.25        0        0        0
# NaN                  Malaysia       2.5     112.5        0        0        0
# ...                       ...       ...       ...      ...      ...      ...
# NaN                  Dominica    15.415   /61.371        0        0        0
# NaN                   Grenada   12.1165   /61.679        0        0        0
# NaN                Mozambique  /18.6657   35.5296        0        0        0
# NaN                     Syria   34.8021   38.9968        0        0        0
# NaN               Timor/Leste   /8.8742  125.7275        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  3/13/20  3/14/20  \
# Province/State                                      ...
# NaN                   7        8        8       14  ...       75       82
# NaN                   2        4        4        7  ...      701      773
# NaN                   3        4        5        7  ...      200      212
# NaN                   1        1        1        1  ...        1        1
# NaN                   3        4        4        4  ...      197      238
# ...                 ...      ...      ...      ...  ...      ...      ...
# NaN                   0        0        0        0  ...        0        0
# NaN                   0        0        0        0  ...        0        0
# NaN                   0        0        0        0  ...        0        0
# NaN                   0        0        0        0  ...        0        0
# NaN                   0        0        0        0  ...        0        0
#
#                 3/15/20  3/16/20  3/17/20  3/18/20  3/19/20  3/20/20  3/21/20  \
# Province/State
# NaN                 114      147      177      212      272      322      411
# NaN                 839      825      878      889      924      963     1007
# NaN                 226      243      266      313      345      385      432
# NaN                   1        1        1        1        1        1        1
# NaN                 428      566      673      790      900     1030     1183
# ...                 ...      ...      ...      ...      ...      ...      ...
# NaN                   0        0        0        0        0        0        0
# NaN                   0        0        0        0        0        0        0
# NaN                   0        0        0        0        0        0        0
# NaN                   0        0        0        0        0        0        0
# NaN                   0        0        0        0        0        0        0
#
#                 3/22/20
# Province/State
# NaN                 599
# NaN                1086
# NaN                 455
# NaN                   2
# NaN                1306
# ...                 ...
# NaN                   1
# NaN                   1
# NaN                   1
# NaN                   1
# NaN                   1
#
# [487 rows x 64 columns]

# %%
#Dropped the columns whose total number of positive cases on a particular day were less than 70%
for i in df_covid.columns:
  var=0.7*df_covid[i].count()
  if len(df_covid[df_covid[i]==0])>var:
    df_covid.drop([i],axis=1,inplace=True)
df_covid.columns
# Out:
# Index(['Country/Region', 'Lat', 'Long', '03-04-2020', '03-05-2020',
#        '03-06-2020', '03-07-2020', '03-08-2020', '03-09-2020', '03-10-2020',
#        '03-11-2020', '03-12-2020', '3/13/20', '3/14/20', '3/15/20', '3/16/20',
#        '3/17/20', '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20'],
#       dtype='object')

# %%
column_list=[]
column_list=df_covid.columns
column_list
# Out:
# Index(['Country/Region', 'Lat', 'Long', '03-04-2020', '03-05-2020',
#        '03-06-2020', '03-07-2020', '03-08-2020', '03-09-2020', '03-10-2020',
#        '03-11-2020', '03-12-2020', '3/13/20', '3/14/20', '3/15/20', '3/16/20',
#        '3/17/20', '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20'],
#       dtype='object')

# %%
country_dict=dict()
for i in range(487):
     #print(df_covid.iloc[i][-1]) 
             # values of last column
    country_dict[df_covid.iloc[i][0]]=country_dict.get(df_covid.iloc[i][0],0+df_covid.iloc[i][-1])

country_dict
# Out:
# {'Thailand': 599,
#  'Japan': 1086,
#  'Singapore': 455,
#  'Nepal': 2,
#  'Malaysia': 1306,
#  'Canada': 424,
#  'Australia': 533,
#  'Cambodia': 84,
#  'Sri Lanka': 82,
#  'Germany': 24873,
#  'Finland': 626,
#  'United Arab Emirates': 153,
#  'Philippines': 380,
#  'India': 396,
#  'Italy': 59138,
#  'Sweden': 1934,
#  'Spain': 28768,
#  'Belgium': 3401,
#  'Egypt': 327,
#  'Lebanon': 248,
#  'Iraq': 233,
#  'Oman': 55,
#  'Afghanistan': 40,
#  'Bahrain': 332,
#  'Kuwait': 188,
#  'Algeria': 201,
#  'Croatia': 254,
#  'Switzerland': 7245,
#  'Austria': 3244,
#  'Israel': 1071,
#  'Pakistan': 776,
#  'Brazil': 1593,
#  'Georgia': 54,
#  'Greece': 624,
#  'North Macedonia': 114,
#  'Norway': 2383,
#  'Romania': 433,
#  'Estonia': 326,
#  'San Marino': 160,
#  'Belarus': 76,
#  'Iceland': 568,
#  'Lithuania': 131,
#  'Mexico': 251,
#  'New Zealand': 66,
#  'Nigeria': 30,
#  'Ireland': 906,
#  'Luxembourg': 798,
#  'Monaco': 23,
#  'Qatar': 494,
#  'Ecuador': 789,
#  'Azerbaijan': 65,
#  'Armenia': 194,
#  'Dominican Republic': 202,
#  'Indonesia': 514,
#  'Portugal': 1600,
#  'Andorra': 113,
#  'Latvia': 139,
#  'Morocco': 115,
#  'Saudi Arabia': 511,
#  'Senegal': 67,
#  'Argentina': 225,
#  'Chile': 632,
#  'Jordan': 112,
#  'Ukraine': 73,
#  'Hungary': 131,
#  'Liechtenstein': 37,
#  'Poland': 634,
#  'Tunisia': 75,
#  'Bosnia and Herzegovina': 126,
#  'Slovenia': 414,
#  'South Africa': 274,
#  'Bhutan': 2,
#  'Cameroon': 40,
#  'Colombia': 231,
#  'Costa Rica': 134,
#  'Peru': 363,
#  'Serbia': 222,
#  'Slovakia': 185,
#  'Togo': 16,
#  'Malta': 90,
#  'Martinique': 37,
#  'Bulgaria': 187,
#  'Maldives': 13,
#  'Bangladesh': 27,
#  'Paraguay': 22,
#  'Albania': 89,
#  'Cyprus': 95,
#  'Brunei': 88,
#  'US': 1996,
#  'Burkina Faso': 75,
#  'Holy See': 1,
#  'Mongolia': 10,
#  'Panama': 245,
#  'China': 67800,
#  'Iran': 21638,
#  'Korea, South': 8897,
#  'France': 16018,
#  'Cruise Ship': 712,
#  'Denmark': 1395,
#  'Czechia': 1120,
#  'Taiwan*': 169,
#  'Vietnam': 113,
#  'Russia': 367,
#  'Moldova': 94,
#  'Bolivia': 24,
#  'Honduras': 26,
#  'United Kingdom': 32,
#  'Congo (Kinshasa)': 30,
#  "Cote d'Ivoire": 14,
#  'Jamaica': 16,
#  'Turkey': 1236,
#  'Cuba': 35,
#  'Guyana': 7,
#  'Kazakhstan': 60,
#  'Ethiopia': 11,
#  'Sudan': 2,
#  'Guinea': 2,
#  'Kenya': 15,
#  'Antigua and Barbuda': 1,
#  'Uruguay': 135,
#  'Ghana': 24,
#  'Namibia': 3,
#  'Seychelles': 7,
#  'Trinidad and Tobago': 50,
#  'Venezuela': 70,
#  'Eswatini': 4,
#  'Gabon': 5,
#  'Guatemala': 19,
#  'Mauritania': 2,
#  'Rwanda': 19,
#  'Saint Lucia': 2,
#  'Saint Vincent and the Grenadines': 1,
#  'Suriname': 5,
#  'Kosovo': 2,
#  'Central African Republic': 3,
#  'Congo (Brazzaville)': 3,
#  'Equatorial Guinea': 6,
#  'Uzbekistan': 43,
#  'Netherlands': 4204,
#  'Benin': 2,
#  'Liberia': 3,
#  'Somalia': 1,
#  'Tanzania': 12,
#  'Barbados': 14,
#  'Montenegro': 21,
#  'Kyrgyzstan': 14,
#  'Mauritius': 18,
#  'Zambia': 3,
#  'Djibouti': 1,
#  'Gambia, The': 1,
#  'Bahamas, The': 4,
#  'Chad': 1,
#  'El Salvador': 3,
#  'Fiji': 2,
#  'Nicaragua': 2,
#  'Madagascar': 3,
#  'Haiti': 2,
#  'Angola': 2,
#  'Cabo Verde': 3,
#  'Niger': 2,
#  'Papua New Guinea': 1,
#  'Zimbabwe': 3,
#  'Cape Verde': 1,
#  'East Timor': 1,
#  'Eritrea': 1,
#  'Uganda': 1,
#  'Dominica': 1,
#  'Grenada': 1,
#  'Mozambique': 1,
#  'Syria': 1,
#  'Timor/Leste': 1}

# %%
#The labels are computed in such a way that only those countries having Corona positive cummulatively 
#of all the days more than 1500 are plotted in the pie chart and the rest are combined and shown as Others. 
x=0
summ=0
country_labels=[]
country_sizes=[]
other_labels=[]
other_sizes=[]
for key,value in country_dict.items():
  if int(value)>=1500:
    country_labels.append(key)
    country_sizes.append(value)
  else:
    summ=summ+int(value)
country_labels.append('Others')
country_sizes.append(summ)
print(country_labels)
print(country_sizes)
# Out:
# ['Germany', 'Italy', 'Sweden', 'Spain', 'Belgium', 'Switzerland', 'Austria', 'Brazil', 'Norway', 'Portugal', 'US', 'China', 'Iran', 'Korea, South', 'France', 'Netherlands', 'Others']
# [24873, 59138, 1934, 28768, 3401, 7245, 3244, 1593, 2383, 1600, 1996, 67800, 21638, 8897, 16018, 4204, 28530]

# %%
#Country wise plot of Corona positive cases
plt.rcParams.update({'font.size': 22})
fig = plt.figure(figsize=[40, 40])
ax = fig.add_subplot(111)
sizes=country_sizes
pie_wedge_collection = ax.pie(sizes, labels=country_labels, labeldistance=1.05,shadow=True)
for pie_wedge in pie_wedge_collection[0]:
    pie_wedge.set_edgecolor('white')
    

ax.set_title( "Figure 1: Country wise plot of Corona positive cases",fontsize=20)
ax.axis('equal')
ax.legend(loc='lower right',bbox_to_anchor=(1.2, 0.5),fontsize=20)

# %% [markdown]
# # Date Wise Plot

# %%
df_covid.columns
# Out:
# Index(['Country/Region', 'Lat', 'Long', '03-04-2020', '03-05-2020',
#        '03-06-2020', '03-07-2020', '03-08-2020', '03-09-2020', '03-10-2020',
#        '03-11-2020', '03-12-2020', '3/13/20', '3/14/20', '3/15/20', '3/16/20',
#        '3/17/20', '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20'],
#       dtype='object')

# %%
#Computed the sum of Corona positive cases date wise and put it in a new row of the dataframe
drop_columns=['Lat', 'Long','Country/Region']
for i in range(0,len(drop_columns)):
  if drop_columns!=0:
    df_covid.drop(labels=drop_columns[i],axis=1,inplace=True)
    i=i-1
dates_list=[]
for col in df_covid.columns:
   dates_list.append(col)
print(dates_list)
df_covid.loc['Total'] = pd.Series(df_covid.sum())
datewise_sum=[]
for value in df_covid.iloc[-1].values:
  datewise_sum.append(value)
print(datewise_sum)
# Out:
# ['03-04-2020', '03-05-2020', '03-06-2020', '03-07-2020', '03-08-2020', '03-09-2020', '03-10-2020', '03-11-2020', '03-12-2020', '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20']
# [95118, 97881, 101784, 105821, 109795, 113561, 118592, 125865, 128343, 145193, 156094, 167446, 181527, 197142, 214910, 242708, 272166, 304524, 335955]

# %%
#Date wise plot of Corona positive cases
plt.rcParams.update({'font.size': 10})
sizes=datewise_sum
labels=dates_list
fig = plt.figure(figsize=[20, 20])
ax = fig.add_subplot(111)
pie_wedge_collection = ax.pie(sizes, labels=labels, labeldistance=1.05)
for pie_wedge in pie_wedge_collection[0]:
    pie_wedge.set_edgecolor('white')
    

ax.set_title( "Figure 2: Datewise wise plot of Corona positive cases",fontsize=24)
ax.axis('equal')
ax.legend(loc='lower right',bbox_to_anchor=(1.2, 0.5),fontsize=10)
